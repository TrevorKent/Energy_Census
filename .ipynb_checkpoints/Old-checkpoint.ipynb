# %% [markdown]
# Energy_Census

# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.style.use('seaborn-whitegrid')

# %%
Data = pd.read_csv("Energy Census and Economic Data US 2010-2014.csv")
Data.count()
# Out:
# StateCodes               52
# State                    52
# Region                   51
# Division                 51
# Coast                    51
# Great Lakes              51
# TotalC2010               52
# TotalC2011               52
# TotalC2012               52
# TotalC2013               52
# TotalC2014               52
# TotalP2010               52
# TotalP2011               52
# TotalP2012               52
# TotalP2013               52
# TotalP2014               52
# TotalE2010               52
# TotalE2011               52
# TotalE2012               52
# TotalE2013               52
# TotalE2014               52
# TotalPrice2010           52
# TotalPrice2011           52
# TotalPrice2012           52
# TotalPrice2013           52
# TotalPrice2014           52
# TotalC10-11              52
# TotalC11-12              52
# TotalC12-13              52
# TotalC13-14              52
#                          ..
# CENSUS2010POP            52
# POPESTIMATE2010          52
# POPESTIMATE2011          52
# POPESTIMATE2012          52
# POPESTIMATE2013          52
# POPESTIMATE2014          52
# RBIRTH2011               52
# RBIRTH2012               52
# RBIRTH2013               52
# RBIRTH2014               52
# RDEATH2011               52
# RDEATH2012               52
# RDEATH2013               52
# RDEATH2014               52
# RNATURALINC2011          52
# RNATURALINC2012          52
# RNATURALINC2013          52
# RNATURALINC2014          52
# RINTERNATIONALMIG2011    52
# RINTERNATIONALMIG2012    52
# RINTERNATIONALMIG2013    52
# RINTERNATIONALMIG2014    52
# RDOMESTICMIG2011         51
# RDOMESTICMIG2012         51
# RDOMESTICMIG2013         51
# RDOMESTICMIG2014         51
# RNETMIG2011              52
# RNETMIG2012              52
# RNETMIG2013              52
# RNETMIG2014              52
# Length: 192, dtype: int64

# %%
Data_Reduced = Data[["State", "StateCodes", "Region", "Division", "Coast", "Great Lakes", "TotalC2010", "TotalC2011", "TotalC2012", "TotalC2013", "TotalC2014", 
                     "TotalP2010", "TotalP2011", "TotalP2012", "TotalP2013", "TotalP2014",
                     "TotalE2010", "TotalE2011", "TotalE2012", "TotalE2013", "TotalE2014"]]
Data_Reduced = Data_Reduced[Data_Reduced.State != "United States"] 
Data_Reduced = Data_Reduced[Data_Reduced.State != "District of Columbia"]
Data_Reduced = Data_Reduced.sort_values(by=['TotalC2010'], ascending=False)
Data_Reduced.head()
# Out:
#          State StateCodes  Region  Division  Coast  Great Lakes  TotalC2010  \
# 42       Texas         TX     3.0       7.0    1.0          0.0    11687521
# 4   California         CA     4.0       9.0    1.0          0.0     7760629
# 17   Louisiana         LA     3.0       7.0    1.0          0.0     4385758
# 8      Florida         FL     3.0       5.0    1.0          0.0     4282673
# 12    Illinois         IL     2.0       3.0    0.0          1.0     3955091
#
#     TotalC2011  TotalC2012  TotalC2013  ...  TotalP2010  TotalP2011  \
# 42    11906249    11931169    12660976  ...    11412134    12571450
# 4      7777115     7564063     7665241  ...     2532205     2634789
# 17     4388867     4255161     4196622  ...     3170742     3972994
# 8      4141711     4029903     4076406  ...      510201      500907
# 12     3937616     3820547     3991089  ...     2090939     2189423
#
#     TotalP2012  TotalP2013  TotalP2014  TotalE2010  TotalE2011  TotalE2012  \
# 42    14180982    15688922    17597105    135014.3    163261.8    152010.2
# 4      2334863     2390424     2413494    117090.0    135097.7    135932.0
# 17     3789540     3208044     2852411     44999.5     53391.3     44310.8
# 8       442188      542570      553738     59825.6     67345.1     66380.0
# 12     2436702     2519993     2683815     45326.7     50877.8     47883.4
#
#     TotalE2013  TotalE2014
# 42    158213.9    162555.8
# 4     137050.7    137719.8
# 17     44637.9     45399.7
# 8      66108.5     66413.6
# 12     49122.2     51550.0
#
# [5 rows x 21 columns]

# %%
years = ["2010", "2011", "2012", "2013", "2014"]
years
# Out:
# ['2010', '2011', '2012', '2013', '2014']

# %%
for year in years:

    # Plot Figure Size
    plt.figure(figsize=(10,4))

    # Plot Data
    plt.bar(Data_Reduced["StateCodes"], Data_Reduced["TotalC"+year], width=.9, align="center", label ="Consumption")
    plt.bar(Data_Reduced["StateCodes"], Data_Reduced["TotalP"+year], width=.4, align="center", label ="Production")

    # Tick locations
    State = Data_Reduced["StateCodes"]
    x_axis = np.arange(len(State))
    tick_locations = [value for value in x_axis]
    plt.xticks(tick_locations, State, rotation=90, fontsize="x-small")

    # Plot Titles
    plt.title(year+" Energy Consumption vs. Production (State Level)")
    # p.xlabel("State")
    plt.ylabel("BTU's")

    # Margins
    plt.margins(x=.005)

    # Plot Legend
    plt.legend(fontsize="small")

    plt.tight_layout()
    plt.show()

    # Save Image
    SaveFile=("Output/"+year+"CP_State")
    plt.savefig(SaveFile)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %%
# Tip
# Helpful ways to get current figure and current axis from most recent plot
# plt.gcf()
# plt.gca()
