# %% [markdown]
# Energy_Census

# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


import matplotlib.style as style 
# style.available

# %%
plt.style.use('fast')

# %%
Data = pd.read_csv("Energy Census and Economic Data US 2010-2014.csv")
Data.count()
# Out:
# StateCodes               52
# State                    52
# Region                   51
# Division                 51
# Coast                    51
# Great Lakes              51
# TotalC2010               52
# TotalC2011               52
# TotalC2012               52
# TotalC2013               52
# TotalC2014               52
# TotalP2010               52
# TotalP2011               52
# TotalP2012               52
# TotalP2013               52
# TotalP2014               52
# TotalE2010               52
# TotalE2011               52
# TotalE2012               52
# TotalE2013               52
# TotalE2014               52
# TotalPrice2010           52
# TotalPrice2011           52
# TotalPrice2012           52
# TotalPrice2013           52
# TotalPrice2014           52
# TotalC10-11              52
# TotalC11-12              52
# TotalC12-13              52
# TotalC13-14              52
#                          ..
# CENSUS2010POP            52
# POPESTIMATE2010          52
# POPESTIMATE2011          52
# POPESTIMATE2012          52
# POPESTIMATE2013          52
# POPESTIMATE2014          52
# RBIRTH2011               52
# RBIRTH2012               52
# RBIRTH2013               52
# RBIRTH2014               52
# RDEATH2011               52
# RDEATH2012               52
# RDEATH2013               52
# RDEATH2014               52
# RNATURALINC2011          52
# RNATURALINC2012          52
# RNATURALINC2013          52
# RNATURALINC2014          52
# RINTERNATIONALMIG2011    52
# RINTERNATIONALMIG2012    52
# RINTERNATIONALMIG2013    52
# RINTERNATIONALMIG2014    52
# RDOMESTICMIG2011         51
# RDOMESTICMIG2012         51
# RDOMESTICMIG2013         51
# RDOMESTICMIG2014         51
# RNETMIG2011              52
# RNETMIG2012              52
# RNETMIG2013              52
# RNETMIG2014              52
# Length: 192, dtype: int64

# %%
Data_Reduced = Data[["State", "StateCodes", "Region", "Division", "Coast", "Great Lakes", 
                     "TotalC2010", "TotalC2011", "TotalC2012", "TotalC2013", "TotalC2014", 
                     "TotalP2010", "TotalP2011", "TotalP2012", "TotalP2013", "TotalP2014",
                     "TotalE2010", "TotalE2011", "TotalE2012", "TotalE2013", "TotalE2014",
                     "TotalPrice2010", "TotalPrice2011", "TotalPrice2012", "TotalPrice2013", "TotalE2014",
                     "POPESTIMATE2010", "POPESTIMATE2011", "POPESTIMATE2012", "POPESTIMATE2013", "POPESTIMATE2014"]]
Data_Reduced = Data_Reduced[Data_Reduced.State != "United States"] 
Data_Reduced = Data_Reduced[Data_Reduced.State != "District of Columbia"]
Data_Reduced = Data_Reduced.sort_values(by=['TotalC2010'], ascending=False)
Data_Reduced.head()
# Out:
#          State StateCodes  Region  Division  Coast  Great Lakes  TotalC2010  \
# 42       Texas         TX     3.0       7.0    1.0          0.0    11687521
# 4   California         CA     4.0       9.0    1.0          0.0     7760629
# 17   Louisiana         LA     3.0       7.0    1.0          0.0     4385758
# 8      Florida         FL     3.0       5.0    1.0          0.0     4282673
# 12    Illinois         IL     2.0       3.0    0.0          1.0     3955091
#
#     TotalC2011  TotalC2012  TotalC2013  ...  TotalPrice2010  TotalPrice2011  \
# 42    11906249    11931169    12660976  ...           17.36           20.55
# 4      7777115     7564063     7665241  ...           20.97           24.35
# 17     4388867     4255161     4196622  ...           15.06           17.96
# 8      4141711     4029903     4076406  ...           22.05           25.41
# 12     3937616     3820547     3991089  ...           17.39           19.53
#
#     TotalPrice2012  TotalPrice2013  TotalE2014  POPESTIMATE2010  \
# 42           19.10           19.08    162555.8         25245717
# 4            24.97           24.85    137719.8         37336011
# 17           15.46           15.67     45399.7          4545581
# 8            25.56           25.13     66413.6         18852220
# 12           19.35           18.54     51550.0         12840097
#
#     POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014
# 42         25657477         26094422         26505637         26956958
# 4          37701901         38062780         38431393         38802500
# 17          4575972          4604744          4629284          4649676
# 8          19107900         19355257         19600311         19893297
# 12         12858725         12873763         12890552         12880580
#
# [5 rows x 31 columns]

# %%
years = ["2010", "2011", "2012", "2013", "2014"]
years
# Out:
# ['2010', '2011', '2012', '2013', '2014']

# %%
c = ['green', 'blue', 'red', 'orange']
c
# Out:
# ['green', 'blue', 'red', 'orange']

# %%
# Loop through each year creating plots 
#for year in years:

    
BTUCap = Data_Reduced["TotalC2010"]/Data_Reduced["POPESTIMATE2010"]
Price = Data_Reduced["TotalPrice2010"]
Pop = Data_Reduced["POPESTIMATE2010"]
States = Data_Reduced["StateCodes"]



plt.figure(figsize=(8,12))
    
plt.scatter(BTUCap, Price, s=Pop/10000, c="red", marker="o", edgecolor="black", linewidths=1,
              alpha=0.3, label="Price")

for i in range(len(States)):
    plt.annotate(States[i], xy=(BTUCap[i], Price[i]), fontsize=8, 
                 horizontalalignment='center', verticalalignment='center')   

# Diplay results
plt.tight_layout
plt.title("Price Vs. Per Capita Consumpution \n (State Level)")
plt.ylabel("Price per BTU (USD$)")
plt.xlabel("Per Capita BTU Consumption (USD$)")
plt.grid()
plt.show()
    
    #BTUCap.head()
    #Price.head()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Tip
# Helpful ways to get current figure and current axis from most recent plot
# plt.gcf()
# plt.gca()

# %%
#fig = plt.figure(ncols=1, nrows=2)

    # Plot figure size
    # fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
    fig1, ax1 = plt.subplots(figsize=(9, 3))
    fig1, ax2 = plt.subplots(figsize=(9, 5))

    # ax1 ---------- ax1 ---------- ax1 ---------- ax1 ---------- ax1 #
    
    # Plot data
    ax1.bar(Data_Reduced["StateCodes"], Data_Reduced["TotalC"+year], width=.9, align="center", label ="Consumption")
    ax1.bar(Data_Reduced["StateCodes"], Data_Reduced["TotalP"+year], width=.4, align="center", label ="Production")

    # Rotate x-axis labels 90 degrees for ax1
    for tick in ax1.get_xticklabels():
        tick.set_rotation(90)
    
    # Plot titles and labels (as needed)
    ax1.set_title(year+"CY"+" Energy Consumption vs. Production\n(State Level)")
    ax1.set_ylabel("BTU's")
    
    # Adjust margins
    ax1.margins(x=.005)
    
    # Plot and format legend
    ax1.legend(loc="upper right", fontsize="small")
   
    # Diplay results
    plt.tight_layout
    plt.show()
    
    # ax2 ---------- ax2 ---------- ax2 ---------- ax2 ---------- ax2 #

    # Save Image
    # SaveFile=("Output/"+year+"CP_State")
    # fig1.savefig(SaveFile)
    
    # Diplay results
    plt.tight_layout
    plt.grid()
    plt.show()
